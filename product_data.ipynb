# %%
import pandas as pd

# %%
Data = pd.read_csv("C:/Users/RITIKA VERMA/Desktop/selenium/product_data.csv")

# %%
Data.head(50)
# Out:
#                                          Product Name  Product Price  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2   Apple iPhone 8 64GB GSM Unlocked Smartphone- V...     US $105.00
# 3         Samsung Galaxy A03s - UNLOCKED - Android 13   US $99.99/ea
# 4   Samsung Galaxy A50 SM-A505U 64GB+4GB RAM 25MP ...     US $129.00
# 5   Samsung Galaxy Z Flip3 5G F711U 128GB Unlocked...     US $299.95
# 6   Unlocked Samsung Galaxy Folder G1600 Dual SIM ...      US $88.00
# 7   New Sealed--BlackBerry Classic Q20 16GB+2GB RA...     US $105.00
# 8   NEW UNLOCKED SAMSUNG GALAXY S20+ PLUS 5G 128/2...  US $216.60/ea
# 9   Lot Of 20 Electronic Phones and Tablets - Work...      US $31.00
# 10  For i16Pro Mini Unlocked Flip Mobile Phone 2 S...      US $35.09
# 11  NEW Samsung Galaxy Note 20 5G SM-N981U 128GB U...     US $245.10
# 12  Working well Apple iPhone 5 5c 5s 8/16/32/64GB...   US $28.99/ea
# ...
